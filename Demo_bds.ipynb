# %%
import pandas as pd
df = pd.read_excel("E:\Python 2023\BẢNG HÀNG TRỐNG AN BÌNH HOME.xlsx",  header=None, skiprows=3)
df.columns = df.iloc[0]
df = df.drop(0)

# %%
df
# Out:
# 0                              ĐỊA CHỈ LOẠI PHÒNG                SĐT DẪN  \
# 1                   QUẬN: HAI BÀ TRƯNG        NaN                    NaN
# 2                    15 BÙI NGỌC DƯƠNG     STUDIO  0969062029\n Anh Ngọc
# 3                                  NaN     STUDIO                    NaN
# 4                                  NaN     STUDIO                    NaN
# 5              NGÁCH 16 NGÕ HÒA BÌNH 4     STUDIO   033 961 5119 \nA BẢO
# ..                                 ...        ...                    ...
# 62  Số 5, Ngách 33, Ngõ 40 Phương Liệt     STUDIO    0962 112 632 A HIẾU
# 63                                 NaN        NaN                    NaN
# 64            NGÁCH 7, NGÕ 354 LÊ DUẨN     Studio     033 961 5119 A BẢO
# 65                                 NaN     STUDIO                    NaN
# 66                                 NaN     Studio                    NaN
#
# 0  SỐ LƯỢNG PHÒNG TRỐNG    PHÒNG / TẦNG   GIÁ CHỐT            TÌNH TRẠNG  \
# ...

# %%
df = df.dropna(subset=['PHÒNG / TẦNG'])
df
# Out:
# 0                              ĐỊA CHỈ LOẠI PHÒNG                SĐT DẪN  \
# 2                    15 BÙI NGỌC DƯƠNG     STUDIO  0969062029\n Anh Ngọc
# 3                                  NaN     STUDIO                    NaN
# 4                                  NaN     STUDIO                    NaN
# 5              NGÁCH 16 NGÕ HÒA BÌNH 4     STUDIO   033 961 5119 \nA BẢO
# 6                                  NaN     STUDIO                    NaN
# ..                                 ...        ...                    ...
# 60                                 NaN     STUDIO                    NaN
# 62  Số 5, Ngách 33, Ngõ 40 Phương Liệt     STUDIO    0962 112 632 A HIẾU
# 64            NGÁCH 7, NGÕ 354 LÊ DUẨN     Studio     033 961 5119 A BẢO
# 65                                 NaN     STUDIO                    NaN
# 66                                 NaN     Studio                    NaN
#
# 0  SỐ LƯỢNG PHÒNG TRỐNG    PHÒNG / TẦNG   GIÁ CHỐT            TÌNH TRẠNG  \
# ...

# %%
df["ĐỊA CHỈ"] = df["ĐỊA CHỈ"].fillna(method='ffill')
df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4984\131524459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ĐỊA CHỈ"] = df["ĐỊA CHỈ"].fillna(method='ffill')
# 0                              ĐỊA CHỈ LOẠI PHÒNG                SĐT DẪN  \
# 2                    15 BÙI NGỌC DƯƠNG     STUDIO  0969062029\n Anh Ngọc
# 3                    15 BÙI NGỌC DƯƠNG     STUDIO                    NaN
# 4                    15 BÙI NGỌC DƯƠNG     STUDIO                    NaN
# 5              NGÁCH 16 NGÕ HÒA BÌNH 4     STUDIO   033 961 5119 \nA BẢO
# 6              NGÁCH 16 NGÕ HÒA BÌNH 4     STUDIO                    NaN
# ..                                 ...        ...                    ...
# ...

# %%
new_df = df[["ĐỊA CHỈ", "PHÒNG / TẦNG", "TÌNH TRẠNG" ]]
new_df
# Out:
# 0                              ĐỊA CHỈ    PHÒNG / TẦNG            TÌNH TRẠNG
# 2                    15 BÙI NGỌC DƯƠNG        TẦNG 4,5            ĐANG TRỐNG
# 3                    15 BÙI NGỌC DƯƠNG  TẦNG 1,2,3,4,5            ĐANG TRỐNG
# 4                    15 BÙI NGỌC DƯƠNG        TẦNG 2,3            ĐANG TRỐNG
# 5              NGÁCH 16 NGÕ HÒA BÌNH 4          TẦNG 1            ĐANG TRỐNG
# 6              NGÁCH 16 NGÕ HÒA BÌNH 4          TẦNG 6            ĐANG TRỐNG
# ..                                 ...             ...                   ...
# 60                  SỐ 663 TRƯƠNG ĐỊNH          TẦNG 3            ĐANG TRỐNG
# 62  Số 5, Ngách 33, Ngõ 40 Phương Liệt  TẦNG 2,3,4,5,6            ĐANG TRỐNG
# 64            NGÁCH 7, NGÕ 354 LÊ DUẨN          TẦNG 3            ĐANG TRỐNG
# 65            NGÁCH 7, NGÕ 354 LÊ DUẨN          Tầng 3  Ngày 1.11 vào ở được
# 66            NGÁCH 7, NGÕ 354 LÊ DUẨN          TẦNG 6            ĐANG TRỐNG
#
# [61 rows x 3 columns]

# %%
new_df.to_excel('demo.xlsx', index=False)
